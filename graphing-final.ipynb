# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scienceplots

plt.rcParams['figure.dpi'] = 300
plt.style.use(['science', 'vibrant'])
plt.rcParams.update({'font.size': 7})

# %% [markdown]
# ### Feature graphs

# %% [markdown]
# ##### ACSIncome

# %%
epsilons = ("0.001", "0.01", "0.1", "0.25", "0.5", "1.0", "2.0", "5.0")

labels = ['LR-F', 'LR-M', 'NB-F', 'NB-M', 'LGBM-F', 'LGBM-M']

lr_f = [0.139, 0.121, 0.117, 0.08, 0.078, 0.079, 0.079, 0.079]
lr_m = [0.18, 0.177, 0.147, 0.087, 0.036, 0.035, 0.035, 0.035]

nb_f = [0.148, 0.122, 0.134, 0.086, 0.077, 0.08, 0.08, 0.08]
nb_m = [0.176, 0.162, 0.144, 0.075, 0.056, 0.059, 0.059, 0.059]

lgbm_f = [0.179, 0.173, 0.19, 0.171, 0.083, 0.074, 0.08, 0.08]
lgbm_m = [0.204, 0.2, 0.195, 0.157, 0.072, 0.056, 0.061, 0.064]

income = [lr_f, lr_m, nb_f, nb_m, lgbm_f, lgbm_m]
colors = ['C0', 'C0', 'C1', 'C1', 'C2', 'C2']
x = np.arange(len(epsilons)) 

fig, ax = plt.subplots()
plt.figure(figsize=(20,12))
ax.set_ylim([0, 0.25])
for i, (data, label, c) in enumerate(zip(income, labels, colors)):
    if i % 2 == 0:
        ax.plot(x, data, label=label, color=c)
    else:
        ax.plot(x, data, label=label, linestyle='--', color=c)

ax.set_ylabel('$\Delta^*_{acc}$', fontsize="8")
ax.set_xlabel('$\epsilon$', fontsize="8")
ax.set_title('Difference in Test Accuracy vs. $\epsilon$', fontsize="8")

ax.set_xticks(x, epsilons, fontsize="7", rotation=0)
ax.legend(loc='upper right', ncol=1, fontsize="6", frameon=False)

plt.show()

# %% [markdown]
# ##### ACSPubCov

# %%
epsilons = ("0.001", "0.01", "0.1", "0.25", "0.5", "1.0", "2.0", "5.0")

labels = ['LR-D', 'LR-ND', 'NB-D', 'NB-ND', 'LGBM-D', 'LGBM-ND']

lr_f = [0.116, 0.126, 0.125, 0.097, 0.095, 0.141, 0.139, 0.143]
lr_m = [0.201, 0.233, 0.208, 0.227, 0.183, 0.071, 0.09, 0.076]

nb_f = [0.118, 0.13, 0.125, 0.098, 0.127, 0.141, 0.139, 0.143]
nb_m = [0.197, 0.222, 0.208, 0.225, 0.097, 0.071, 0.09, 0.076]

lgbm_f = [0.143, 0.157, 0.151, 0.138, 0.111, 0.102, 0.116, 0.13]
lgbm_m = [0.18, 0.198, 0.185, 0.188, 0.169, 0.12, 0.1, 0.075]

income = [lr_f, lr_m, nb_f, nb_m, lgbm_f, lgbm_m]
colors = ['C0', 'C0', 'C1', 'C1', 'C2', 'C2']
x = np.arange(len(epsilons)) 

fig, ax = plt.subplots()
plt.figure(figsize=(20,12))
ax.set_ylim([0, 0.25])
for i, (data, label, c) in enumerate(zip(income, labels, colors)):
    if i % 2 == 0:
        ax.plot(x, data, label=label, color=c)
    else:
        ax.plot(x, data, label=label, linestyle='--', color=c)

ax.set_ylabel('$\Delta^*_{acc}$', fontsize="8")
ax.set_xlabel('$\epsilon$', fontsize="8")
ax.set_title('Difference in Test Accuracy vs. $\epsilon$', fontsize="8")

ax.set_xticks(x, epsilons, fontsize="7", rotation=0)
ax.legend(loc='upper right', ncol=1, fontsize="6", frameon=False)

plt.show()

# %% [markdown]
# ##### ACSEmployment

# %%
epsilons = ("0.001", "0.01", "0.1", "0.25", "0.5", "1.0", "2.0", "5.0")

labels = ['LR-W', 'LR-NW', 'NB-W', 'NB-NW', 'LGBM-W', 'LGBM-NW']

lr_w = [0.054, 0.057, 0.05, 0.049, 0.024, 0.018, 0.019, 0.016]
lr_nw = [0.096, 0.101, 0.093, 0.087, 0.057, 0.047, 0.047, 0.046]

nb_w = [0.06, 0.064, 0.055, 0.053, 0.027, 0.021, 0.024, 0.021]
nb_nw = [0.096, 0.099, 0.089, 0.085, 0.091, 0.065, 0.066, 0.065]

lgbm_w = [0.087, 0.09, 0.089, 0.091, 0.08, 0.051, 0.031, 0.03]
lgbm_nw = [0.119, 0.123, 0.122, 0.118, 0.099, 0.067, 0.059, 0.057]

income = [lr_w, lr_nw, nb_w, nb_nw, lgbm_w, lgbm_nw]
colors = ['C0', 'C0', 'C1', 'C1', 'C2', 'C2']
x = np.arange(len(epsilons)) 

fig, ax = plt.subplots()
plt.figure(figsize=(20,12))
ax.set_ylim([0, 0.25])
for i, (data, label, c) in enumerate(zip(income, labels, colors)):
    if i % 2 == 0:
        ax.plot(x, data, label=label, color=c)
    else:
        ax.plot(x, data, label=label, linestyle='--', color=c)

ax.set_ylabel('$\Delta^*_{acc}$', fontsize="8")
ax.set_xlabel('$\epsilon$', fontsize="8")
ax.set_title('Difference in Test Accuracy vs. $\epsilon$', fontsize="8")

ax.set_xticks(x, epsilons, fontsize="7", rotation=0)
ax.legend(loc='upper right', ncol=1, fontsize="6", frameon=False)

plt.show()

# %% [markdown]
# ### Labels and Features

# %% [markdown]
# ##### ACSIncome

# %%
epsilons = ("0.001", "0.01", "0.1", "0.25", "0.5", "1.0", "2.0", "5.0")

labels = ['LR-F', 'LR-M', 'NB-F', 'NB-M', 'LGBM-F', 'LGBM-M']

lr_f = [0.233, 0.235, 0.199, 0.167, 0.063, 0.08, 0.079, 0.079]
lr_m = [0.217, 0.23, 0.224, 0.19, 0.063, 0.036, 0.035, 0.035]

nb_f = [0.228, 0.238, 0.216, 0.17, 0.065, 0.081, 0.08, 0.08]
nb_m = [0.226, 0.233, 0.199, 0.191, 0.059, 0.055, 0.059, 0.059]

lgbm_f = [0.226, 0.226, 0.227, 0.22, 0.179, 0.064, 0.08, 0.08]
lgbm_m = [0.223, 0.225, 0.225, 0.214, 0.153, 0.059, 0.057, 0.064]

income = [lr_f, lr_m, nb_f, nb_m, lgbm_f, lgbm_m]
colors = ['C0', 'C0', 'C1', 'C1', 'C2', 'C2']
x = np.arange(len(epsilons)) 

fig, ax = plt.subplots()
plt.figure(figsize=(20,12))
ax.set_ylim([0, 0.25])
for i, (data, label, c) in enumerate(zip(income, labels, colors)):
    if i % 2 == 0:
        ax.plot(x, data, label=label, color=c)
    else:
        ax.plot(x, data, label=label, linestyle='--', color=c)

ax.set_ylabel('$\Delta^*_{acc}$', fontsize="8")
ax.set_xlabel('$\epsilon$', fontsize="8")
ax.set_title('Difference in Test Accuracy vs. $\epsilon$', fontsize="8")

ax.set_xticks(x, epsilons, fontsize="7", rotation=0)
ax.legend(loc='upper right', ncol=1, fontsize="6", frameon=False)

plt.show()

# %% [markdown]
# ##### ACSCPubCov

# %%
epsilons = ("0.001", "0.01", "0.1", "0.25", "0.5", "1.0", "2.0", "5.0")

labels = ['LR-D', 'LR-ND', 'NB-D', 'NB-ND', 'LGBM-D', 'LGBM-ND']

lr_ndis = [0.156, 0.16, 0.154, 0.147, 0.086, 0.136, 0.136, 0.143]
lr_dis = [0.196, 0.168, 0.185, 0.199, 0.193, 0.063, 0.07, 0.084]

nb_ndis = [0.154, 0.16, 0.156, 0.15, 0.092, 0.137, 0.136, 0.143]
nb_dis = [0.194, 0.169, 0.189, 0.193, .166, 0.061, 0.07, 0.084]

lgbm_ndis = [0.161, 0.161, 0.16, 0.16, 0.146, 0.094, 0.114, 0.134]
lgbm_dis = [0.178, 0.177, 0.177, 0.177, 0.179, 0.136, 0.087, 0.083]


income = [lr_ndis, lr_dis, nb_ndis, nb_dis, lgbm_ndis, lgbm_dis]
colors = ['C0', 'C0', 'C1', 'C1', 'C2', 'C2']
x = np.arange(len(epsilons)) 

fig, ax = plt.subplots()
plt.figure(figsize=(20,12))
ax.set_ylim([0, 0.25])
for i, (data, label, c) in enumerate(zip(income, labels, colors)):
    if i % 2 == 0:
        ax.plot(x, data, label=label, color=c)
    else:
        ax.plot(x, data, label=label, linestyle='--', color=c)

ax.set_ylabel('$\Delta^*_{acc}$', fontsize="8")
ax.set_xlabel('$\epsilon$', fontsize="8")
ax.set_title('Difference in Test Accuracy vs. $\epsilon$', fontsize="8")

ax.set_xticks(x, epsilons, fontsize="7", rotation=0)
ax.legend(loc='upper right', ncol=1, fontsize="6", frameon=False)

plt.show()

# %% [markdown]
# ##### ACSEmployment (DONE)

# %%
epsilons = ("0.001", "0.01", "0.1", "0.25", "0.5", "1.0", "2.0", "5.0")

labels = ['LR-W', 'LR-NW', 'NB-W', 'NB-NW', 'LGBM-W', 'LGBM-NW']

lr_w = [0.126, 0.131, 0.124, 0.116, 0.103, 0.085, 0.083, 0.087]
lr_nw = [0.083, 0.092, 0.083, 0.072, 0.019, 0.009, 0.01, 0.009]

nb_w = [0.123, 0.13, 0.122, 0.115, 0.099, 0.087, 0.087, 0.087]
nb_nw = [0.085, 0.098, 0.087, 0.078, 0.02, 0.005, 0.005, 0.004]

lgbm_w = [0.13, 0.13, 0.128, 0.129, 0.128, 0.12, 0.083, 0.075]
lgbm_nw = [0.097, 0.1, 0.098, 0.101, 0.095, 0.049, 0.017, 0.019]


income = [lr_f, lr_m, nb_f, nb_m, lgbm_f, lgbm_m]
colors = ['C0', 'C0', 'C1', 'C1', 'C2', 'C2']
x = np.arange(len(epsilons)) 

fig, ax = plt.subplots()
plt.figure(figsize=(20,12))
ax.set_ylim([0, 0.25])
for i, (data, label, c) in enumerate(zip(income, labels, colors)):
    if i % 2 == 0:
        ax.plot(x, data, label=label, color=c)
    else:
        ax.plot(x, data, label=label, linestyle='--', color=c)
ax.set_ylabel('$\Delta^*_{acc}$', fontsize="8")
ax.set_xlabel('$\epsilon$', fontsize="8")
ax.set_title('Difference in Test Accuracy vs. $\epsilon$', fontsize="8")

ax.set_xticks(x, epsilons, fontsize="7", rotation=0)
ax.legend(loc='upper right', ncol=1, fontsize="6", frameon=False)

plt.show()
